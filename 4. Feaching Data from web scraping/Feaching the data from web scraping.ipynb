# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://www.ambitionbox.com/reviews/deloitte-reviews/sap-abap-consultant?page=1',headers=headers).text

# https://www.ambitionbox.com/reviews/deloitte-reviews/sap-abap-consultant?page=1

# %%
soup=BeautifulSoup(webpage,'lxml') # 'lxml is a html parser kahate hai ye Beautifulsoup ke anger builten function hai

# %%
print(soup.prettify())
# ye function sare html ko sahi se formate kar dega.
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Deloitte SAP Abap Consultant Reviews by 40+ Employees | Rated 3.9/5 | AmbitionBox
#   </title>
#   <meta content="Deloitte SAP Abap Consultant Reviews by 40+ Employees | Rated 3.9/5 | AmbitionBox" name="title"/>
#   <meta content="Deloitte is rated 3.9/5, based on 40+ SAP Abap Consultant reviews on AmbitionBox. Deloitte is highly rated for Skill development with 4.2/5 for SAP Abap Consultant designation." name="description"/>
#   <meta content="width=device-width,initial-scale=1, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://static.ambitionbox.com/alpha/img/supporting-images/browser_icon_16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://static.ambitionbox.com/alpha/img/supporting-images/browser_icon_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# ...

# %%
soup.find_all('h1')[0].text
# Out:
# 'Deloitte SAP Abap Consultant Reviews'

# %%
len(soup.find_all('h2'))
# Out:
# 28

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# Work policies
# 5 days
# Flexible timing
# No travel
# 44 reviews found
# rated by a SAP Abap Consultant in Bengaluru
# rated by a SAP Abap Consultant in Kolkata
# rated by a SAP Abap Consultant in Mumbai
# rated by a SAP Abap Consultant in Pune
# rated by a SAP Abap Consultant in Kolkata
# rated by a SAP Abap Consultant in Hyderabad
# rated by a SAP Abap Consultant in Mumbai
# rated by a SAP Abap Consultant in Hyderabad
# rated by a SAP Abap Consultant in Kolkata
# rated by a SAP Abap Consultant in Bengaluru
# rated by a SAP Abap Consultant in Gurugram
# rated by a SAP Abap Consultant in Mumbai
# rated by a SAP Abap Consultant in Gurugram
# rated by a SAP Abap Consultant in Mumbai
# rated by a SAP Abap Consultant in Mumbai
# rated by a SAP Abap Consultant in Mumbai
# rated by a SAP Abap Consultant in Bengaluru
# rated by a SAP Abap Consultant in Noida
# rated by a SAP Abap Consultant in Hyderabad
# rated by a SAP Abap Consultant in Coimbatore
# SAP Abap Consultant Jobs at Deloitte
# ...

# %%
# soup.find_all('div').text
len(soup.find('div').text)
# Out:
# 20380

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# All rights reserved © 2026 Info Edge (India) Ltd.
# Deloitte
# 90% employees reported
# 84% employees reported
# 61% employees reported
# View more detailed insights
# Work days: 5 days (Strict Timings)
# We can do permanent WFH, if the client aggrees. Work life balance is there.
# Hike is in single digit nowadays. We will be forced to do firm contribution from the higher levels. Also most of the employees are asked to go to client offices and follow their work culture.
# Work policy: 2 days/week from office
# Work days: 5 days (Flexible Timings)
# Work related travel: This is a desk job.
# Its really  nice salary / bonus, wellbeing  subsidies all are nice you will get to learn new technologies
# Work life balance is not that much good here
# Culture
# Work policy: 2 days/week from office
# Work timings: Flexible Timings
# Work related travel: This is a desk job.
# Business formals are allowed, good compensation
# ...

# %%
soup.find_all('p',reaating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 soup.find_all('p',reaating)
#
# NameError: name 'reaating' is not defined
